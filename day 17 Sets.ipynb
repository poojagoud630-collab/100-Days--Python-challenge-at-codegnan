# %%
sets : set is an unordered collection of different datatypes with unique elements.it is mutable and represents with '{ }'
properties: sets allows unique elements except lists and dictionary
set is unordered collection
set not supports indexing  and slicing
sets allows hashable data type elements
EMPTY SET representation : 
s1 = {}
s2= set()
Reading set of numbers:
s=set(map(int,input().split())
set operations:
1. union
2. Intersection 
3. differenece
4. symmetric difference
Checking operation:
5.issubset
6.issuper set
7. isDisjoint sets
##For adding the elements
-->add(element): it adds element to set if element is not in set otherwise nothing.
-->update(iterable) : it add the all  elements in iterator
##For removing the elements
remove(element)  --------->if element is not present then it raises key error
discard(element)
pop()
# Out:
# <>:17: SyntaxWarning: invalid decimal literal
# <>:18: SyntaxWarning: invalid decimal literal
# <>:17: SyntaxWarning: invalid decimal literal
# <>:18: SyntaxWarning: invalid decimal literal
# C:\Users\pooja\AppData\Local\Temp\ipykernel_23372\3089307405.py:17: SyntaxWarning: invalid decimal literal
#   5.issubset
# C:\Users\pooja\AppData\Local\Temp\ipykernel_23372\3089307405.py:18: SyntaxWarning: invalid decimal literal
#   6.issuper set
#   Cell In[2], line 1
#     sets : set is an unordered collection of different datatypes with unique elements.it is mutable and represents with '{ }'
#                      ^
# SyntaxError: invalid syntax

# %%
a={1,2,3,4,5,6}
b={4,5,6,7}
s3=a.union(b)    # /
print(s3)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a={1,2,3,4,5,6}
b={4,5,6}
a.intersection(b)     #  &
# Out:
# {4, 5, 6}

# %%
a={1,2,3,4,5,6}
b={4,5,6,7,8}
a.difference(b)         # -
# Out:
# {1, 2, 3}

# %%
a={1,2,3,4,5,6}
b={4,5,6,7,8}
a.symmetric_difference(b)   #
# Out:
# {1, 2, 3, 7, 8}

# %%
a={1,2,3,4,5,6}
b={4,5,6,7,8}
print({1}.issubset(a))
# Out:
# True

# %%
print(list({12,2,3,4}))
# Out:
# [2, 3, 12, 4]

# %%
#set functions
#adding elements to sets
a={1,2,3,4,5}
a.add(1)
a.add(90)
print(a)
a.update([8,7,9,80])
print(a)
# Out:
# {1, 2, 3, 4, 5, 90}
# {1, 2, 3, 4, 5, 7, 8, 9, 80, 90}

# %%
s1={1,2,3,4,'hi',6,1,2,3,4,78,90}
print(s1)
# Out:
# {1, 2, 3, 4, 6, 78, 'hi', 90}

# %%
a={1,2,3,4,5,70,56,46}
a.remove(1)
a.discard(90)
print(a)
a.discard(5)
print(a)
a.pop()
print(a)
# Out:
# {2, 3, 4, 5, 70, 46, 56}
# {2, 3, 4, 70, 46, 56}
# {3, 4, 70, 46, 56}

# %%
# searching element in list- O(n)    & for set - 1
book management using set & dictionary
set- it stores book reg no
dict- it stores book details
{101 :{'name' : 'python','author':'as'}}
{101:['python' :'as']}
operations   |key              |dict    
1.add book - id,      name,author,quantity
2.delete book - id id - delete from set
                   book - dlete from dict
3.total books -len()
4.allbooks
5.barrow book -
# Out:
#   Cell In[13], line 8
#     1.add book - id,      name,author,quantity
#      ^
# SyntaxError: invalid decimal literal

# %%
# Set to store book IDs
book_ids = set()

# Dictionary to store book details
books = {}

# 1. Add Book
def add_book():
    book_id = int(input("Enter Book ID: "))
    
    if book_id in book_ids:
        print("Book already exists!")
        return
    
    name = input("Enter Book Name: ")
    author = input("Enter Author Name: ")
    quantity = int(input("Enter Quantity: "))
    
    book_ids.add(book_id)
    books[book_id] = {
        'name':name,
        'author': author,
        'quantity': quantity
    }
    print("Book added successfully ")

# 2. Delete Book
def delete_book():
    book_id = int(input("Enter Book ID to delete: "))
    
    if book_id in book_ids:
        book_ids.remove(book_id)
        del books[book_id]
        print("Book deleted successfully ")
    else:
        print("Book not found!")# 
# 3.Total Books       
def total_books():
    print("Total number of books:", len(book_ids))

# 4. Display All Books
def display_books():
    if not books:
        print("No books available.")
        return
    
    for book_id, details in books.items():
        print("\nBook ID:", book_id)
        print("Name:", details['name'])
        print("Author:", details['author'])
        print("Quantity:", details['quantity'])

# 5. Borrow Book
def borrow_book():
    book_id = int(input("Enter Book ID to borrow: "))
    
    if book_id in books:
        if books[book_id]['quantity'] > 0:
            books[book_id]['quantity'] -= 1
            print("Book borrowed successfully ")
        else:
            print("Book out of stock!")
    else:
        print("Book not found!")

# Main Program
def main():
    while True:
        print("\n--- Book Management System ---")
        print("1. Add Book")
        print("2. Delete Book")
        print("3. Total Books")
        print("4. Display All Books")
        print("5. Borrow Book")
        print("6. Exit")
        
        choice = int(input("Enter your choice: "))
        
        if choice == 1:
            add_book()        
        elif choice == 2:    
            delete_book()
        elif choice == 3:
            total_books()
        elif choice == 4:
            display_books()
        elif choice == 5:
            borrow_book()
        elif choice == 6:
            print("Thank you! ")
            break
        else:
            print("Invalid choice!")
main()
# Out:
# --- Book Management System ---
# 1. Add Book
# 2. Delete Book
# 3. Total Books
# 4. Display All Books
# 5. Borrow Book
# 6. Exit
# Enter your choice:  6
# Thank you!
